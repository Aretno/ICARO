# %%
import glob

run_number    = 4718
outputfolder = "/Users/ansimez/Documents/InvCit/hdf5/{}/pmaps/MonitorPlots/".format(run_number)
inputfiles = glob.glob("/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps*_1[0-9][0-9][0-9]*h5".format(run_number))

# %%
len(inputfiles)
# Out:
# 818

# %%
inputfiles
# Out:
# ['/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1000_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1001_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1002_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1003_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1004_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1005_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1006_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1007_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1008_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1009_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1010_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1011_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1012_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1013_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1014_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1015_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1016_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1017_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1018_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1019_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1020_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1021_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1022_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1023_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1024_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1025_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1026_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1027_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1028_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1029_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1030_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1031_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1032_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1033_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1034_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1035_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1036_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1037_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1038_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1039_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1040_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1041_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1042_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1043_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1044_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1045_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1046_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1047_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1048_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1049_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1050_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1051_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1052_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1053_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1054_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1055_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1056_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1057_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1058_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1059_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1060_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1061_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1062_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1063_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1064_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1065_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1066_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1067_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1068_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1069_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1070_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1071_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1072_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1073_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1074_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1075_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1076_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1077_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1078_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1079_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1080_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1081_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1082_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1083_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1084_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1085_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1086_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1087_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1088_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1089_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1090_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1091_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1092_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1093_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1094_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1095_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1096_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1097_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1098_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1099_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1100_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1101_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1102_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1103_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1104_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1105_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1107_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1108_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1109_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1110_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1111_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1112_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1113_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1114_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1115_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1116_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1117_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1118_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1119_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1120_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1121_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1122_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1123_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1124_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1125_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1126_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1127_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1128_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1129_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1130_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1131_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1132_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1133_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1134_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1135_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1136_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1137_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1138_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1139_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1140_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1141_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1142_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1143_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1144_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1145_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1146_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1147_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1148_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1149_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1150_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1151_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1152_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1153_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1154_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1155_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1156_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1157_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1158_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1159_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1160_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1161_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1162_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1163_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1164_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1165_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1166_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1167_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1168_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1169_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1170_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1171_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1172_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1173_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1174_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1175_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1176_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1177_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1178_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1179_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1180_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1181_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1182_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1183_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1184_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1185_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1186_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1187_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1188_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1189_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1190_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1191_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1192_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1193_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1194_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1195_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1196_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1197_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1198_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1199_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1200_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1201_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1202_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1203_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1204_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1205_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1206_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1207_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1208_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1209_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1210_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1211_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1212_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1213_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1214_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1215_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1216_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1217_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1218_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1219_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1220_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1221_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1222_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1223_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1224_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1225_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1226_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1227_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1228_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1229_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1230_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1231_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1232_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1233_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1234_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1235_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1236_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1237_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1238_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1239_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1240_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1241_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1242_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1243_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1244_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1245_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1246_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1247_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1248_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1249_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1250_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1251_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1252_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1253_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1254_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1255_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1256_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1257_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1258_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1259_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1260_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1261_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1262_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1263_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1264_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1265_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1266_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1267_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1268_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1269_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1270_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1271_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1272_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1273_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1274_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1275_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1276_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1277_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1278_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1279_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1280_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1281_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1282_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1283_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1284_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1285_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1286_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1287_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1288_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1289_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1290_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1291_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1292_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1293_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1294_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1295_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1296_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1297_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1298_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1299_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1300_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1301_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1302_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1303_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1304_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1305_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1306_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1307_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1308_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1309_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1310_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1311_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1312_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1313_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1314_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1315_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1316_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1317_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1318_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1319_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1320_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1321_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1322_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1323_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1324_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1325_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1326_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1327_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1328_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1329_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1330_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1331_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1332_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1333_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1334_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1335_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1336_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1337_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1338_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1339_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1340_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1341_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1342_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1343_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1344_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1345_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1346_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1347_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1348_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1349_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1350_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1351_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1352_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1353_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1354_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1355_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1356_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1357_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1358_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1359_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1360_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1361_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1362_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1363_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1364_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1365_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1366_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1367_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1368_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1369_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1370_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1371_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1372_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1373_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1374_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1375_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1376_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1377_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1378_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1379_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1380_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1381_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1382_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1383_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1384_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1385_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1386_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1387_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1388_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1389_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1390_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1391_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1392_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1393_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1394_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1395_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1396_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1397_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1398_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1399_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1400_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1401_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1402_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1403_4718_icdev_20171006_th_th2000.h5',
# ...
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1685_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1686_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1687_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1688_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1689_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1690_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1691_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1692_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1693_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1694_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1695_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1696_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1697_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1698_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1699_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1700_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1701_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1702_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1703_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1704_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1705_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1706_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1707_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1708_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1709_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1710_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1711_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1712_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1713_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1714_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1715_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1716_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1717_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1718_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1719_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1720_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1722_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1723_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1724_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1725_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1726_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1727_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1728_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1729_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1730_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1731_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1732_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1733_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1734_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1735_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1736_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1737_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1738_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1739_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1740_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1741_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1742_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1743_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1744_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1745_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1746_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1747_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1748_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1749_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1750_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1751_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1752_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1753_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1754_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1755_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1756_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1757_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1758_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1759_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1760_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1761_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1762_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1763_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1764_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1765_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1766_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1767_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1768_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1769_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1770_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1771_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1772_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1773_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1774_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1775_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1776_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1777_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1778_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1779_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1780_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1781_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1782_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1783_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1784_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1785_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1786_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1787_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1788_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1789_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1790_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1791_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1792_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1793_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1794_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1795_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1796_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1797_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1798_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1799_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1800_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1801_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1802_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1803_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1804_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1805_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1806_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1807_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1808_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1809_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1810_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1811_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1812_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1813_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1814_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1815_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1816_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1817_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1818_4718_icdev_20171006_th_th2000.h5',
#  '/Users/ansimez/Documents/InvCit/hdf5/Kr_sipm/Th_Cuts/20171006_th/pmaps/pmaps_1819_4718_icdev_20171006_th_th2000.h5']

# %%
import os
import functools
import itertools
import time
print("Running on ", time.asctime())

import numpy             as np
import tables            as tb
import matplotlib.pyplot as plt
import pandas as pd
from matplotlib.colors import LogNorm

import invisible_cities.reco.pmaps_functions  as pmapsf
import invisible_cities.filters.s1s2_filter as s1s2filt
import invisible_cities.database.load_db as dbf
import invisible_cities.io.table_io as tbiof
import invisible_cities.reco.tbl_functions as tbf
import invisible_cities.io.pmap_io as pmapio
import invisible_cities.reco.pmaps_functions_c  as pmapsfc

from invisible_cities.icaro.hst_functions import hist
from invisible_cities.icaro.hst_functions import hist2d
from invisible_cities.icaro.hst_functions import hist2d_profile
from invisible_cities.icaro.hst_functions import labels

from invisible_cities.core.system_of_units_c import units

if not os.path.exists(outputfolder):
    os.mkdir(outputfolder)
# Out:
# Running on  Mon Oct  9 18:08:37 2017

# %%
# %matplotlib inline

np.warnings.filterwarnings('ignore')

plt.rcParams["figure.figsize"]          = 8, 6
plt.rcParams["font.size"]               = 15
plt.rcParams["figure.max_open_warning"] = 100

profOpt = "--k"
fitOpt  = "r"

# %% [markdown]
# ### Load database

# %%
DataSiPM = dbf.DataSiPM(run_number)

# %% [markdown]
# ## Functions

# %% [markdown]
# #### Function for some histo stats (mean and std)

# %%
def weighted_std(values, weights):
    """
    Return the weighted average and standard deviation.

    values, weights -- Numpy ndarrays with the same shape.
    """
    average = np.average(values, weights=weights)
    variance = np.average((values-average)**2, weights=weights)  # Fast and numerically precise
    return [average, np.sqrt(variance)]

# %% [markdown]
# #### Functions for filling variables

# %%
def fillSvar (evt, s_file, sn, sw, sh, se, st, evt_ts, timestamp):
    try: 
        s = s_file[evt]
    except:
        sn.append(0)   
    else:
        peaks = s.peak_collection()
        sn.append(len(peaks))
        for npeak in peaks:
            peak = s.peak_waveform(npeak)
            sw.append(peak.width)
            sh.append(peak.height)
            se.append(np.sum(peak.E))
            st.append(np.mean(peak.t))
            evt_ts.append(timestamp)

# %%
def fillS2PMTvar (s2pmt, sw, sh, se, st, npmt):
    peaks = s2pmt.peak_collection()
    
    for npeak in peaks:
        sw_pmt = []
        sh_pmt = []
        se_pmt = []
        st_pmt = []
        for pmt in np.arange(0,npmt,1):
            peak = s2pmt.pmt_waveform(npeak,pmt)
            sw_pmt.append(peak.width)
            sh_pmt.append(peak.height)
            se_pmt.append(np.sum(peak.E))
            st_pmt.append(np.mean(peak.t))
        sw.append(sw_pmt)
        sh.append(sh_pmt)
        se.append(se_pmt)
        st.append(st_pmt)

# %%
def fillS2var (evt, s2_file, s2si_file, s2n, s2w, s2wthr, s2h, s2e, s2ethr, s2t, \
               s2sin, s2q, s2siID, s2qi, s2qmax, s2nsipm, s2_s2si_e,\
               s1n, s1e, s1t, s2_s1_e, s2_s1_t, onlyS1, \
               evt_tS2, evt_tS2si, evt_tS2sin, timestamp, thr):

    s2 = s2_file[evt]
    peaks = s2.peak_collection()
    s2n.append(len(peaks))
    try:
        s2si = s2si_file[evt]       
    except:
        s2sin.append(0)
    else:
        s2sin.append(len(s2si.s2sid))

    for npeak in peaks:
        peak = s2.peak_waveform(npeak)
        

        s2w.append(peak.width)
        s2wthr.append(peak.width_above_threshold(thr))
        s2h.append(peak.height)
        e = np.sum(peak.E)
        s2e.append(e)
        s2ethr.append(np.sum(peak.total_energy_above_threshold(thr)))
        s2t.append(np.mean(peak.t))
        evt_tS2.append(timestamp)
        
        if(s1n[-1]==1):
            s2_s1_e.append(s2e[-1]/s1e[-1])
            s2_s1_t.append(s2t[-1] - s1t[-1])
            onlyS1.append(True)
        else:
            onlyS1.append(False)
        
        q = 0
        try: 
            sipeaks = s2si.s2sid[npeak]
        except:
            pass
        else:
            evt_tS2si.append(timestamp)
            chargemax = -10000

            for ID, si in sipeaks.items():
                evt_tS2sin.append(timestamp)
                charge = np.sum(si)
                q += charge
                s2qi.append(charge)
                s2siID.append(ID)
                if charge>chargemax :
                    chargemax = charge
                
            s2q.append(q)
            s2qmax.append(chargemax)
            s2nsipm.append(len(sipeaks))
        s2_s2si_e.append(q/e)

# %% [markdown]
# #### Functions for plotting

# %%
def plotVar (var, bins, var_min, var_max, x_label, y_label, title, text="stats", log = False):
    n, x, y = hist(var, bins, [var_min, var_max])
    labels(x_label, y_label, title)
    mean = weighted_std(x, n)
    ypos_text = 0.85*np.max(n)

    if log:
        plt.yscale("log")
        
    if text == "stats":
        plt.text(x[len(x)//2], ypos_text, \
                "Mean = {0:.2f}\n".format(mean[0]) + \
                "RMS = {0:.2f}\n".format(mean[1]))        
    elif text == "":
        pass
    else:
        plt.text(x[len(x)//2], 0.85*np.max(n), text)
    
#    fig.savefig(outputfolder+title+".pdf")

# %%
def plotVarPMT (npmt, var, bins, var_min, var_max, x_label, y_label, title):
    fsize = 30
    
    n_row = 3
    nrows = npmt//n_row

    if npmt%n_row>0:
        nrows +=1
        
    fig, axes = plt.subplots(nrows, 3, figsize=(40,40))
    st = fig.suptitle(title, fontsize = 80)

    for pmt in range(npmt):
        axes[pmt//n_row][pmt%n_row].hist(var[:,pmt], bins, [var_min, var_max])
        axes[pmt//n_row][pmt%n_row].set_xlabel(x_label, fontsize = fsize/2)
        axes[pmt//n_row][pmt%n_row].set_ylabel(y_label, fontsize = fsize/2)
        axes[pmt//n_row][pmt%n_row].set_title("PMT {}".format(pmt), fontsize = fsize)

    fig.tight_layout()
    
    st.set_y(0.98)
    fig.subplots_adjust(top=0.93)
    
#    fig.savefig(outputfolder+title+"PMTs.pdf")

# %%
def plot2dVar(var1, var2, binx, biny, var1_min, var1_max, var2_min, var2_max, x_label, y_label, title, log = False):
    if log == True:
        hist2d(var1, var2, (binx, biny), [[var1_min, var1_max], [var2_min, var2_max]], norm = LogNorm())
    else:
        hist2d(var1, var2, (binx, biny), [[var1_min, var1_max], [var2_min, var2_max]])

    plt.colorbar().set_label("Entries")
    labels(x_label, y_label, title)
    
#    fig.savefig(outputfolder+title+".pdf")

# %%
def plot2dVarPMT(npmt, var1, var2, binx, biny, var1_min, var1_max, var2_min, var2_max, x_label, y_label, title):
    fsize = 30
    
    n_row = 3
    nrows = npmt//n_row

    if npmt%n_row>0:
        nrows +=1
        
    fig, axes = plt.subplots(nrows, 3, figsize=(40,40))
    st = fig.suptitle(title, fontsize = 80)

    for pmt in range(npmt):
        axes[pmt//n_row][pmt%n_row].hist2d(var1, var2[:,pmt], (binx, biny), [[var1_min, var1_max], [var2_min, var2_max]])
        axes[pmt//n_row][pmt%n_row].set_xlabel(x_label, fontsize = fsize/2)
        axes[pmt//n_row][pmt%n_row].set_ylabel(y_label, fontsize = fsize/2)
        axes[pmt//n_row][pmt%n_row].set_title("PMT {}".format(pmt), fontsize = fsize)

    fig.tight_layout()
    
    st.set_y(0.98)
    fig.subplots_adjust(top=0.93)
    
#    fig.savefig(outputfolder+title+"PMTs.pdf")

# %%
def CreatePlotsS(sn, sw, sh, se, st, tE, tS, stype, smin, smax):

    ### Number of peaks
    textPrint = "Total number = {0}\n".format(sn.sum()) + \
            "Higher than 10 = {0}\n".format(len(sn[sn>10])) + \
            "Events with 1 = {0}".format(len(sn[sn==1]))
    plotVar(sn, 10, 0, 10, "# " + stype, "Entries", stype + " number", text  = textPrint)

    ### Width
    plotVar(sw, 100, sw.min(), sw.max(), "Width (ns)", "Entries", stype + " width", text = "", log = True)
    plotVar(sw, 100, smin['w'], smax['w'], "Width (ns)", "Entries", stype + " width (zoom)")

    ### Height
    plotVar(sh, 100, sh.min(), sh.max(), "Height (pes)", "Entries", stype + " height", text = "", log = True)
    plotVar(sh, 100, smin['h'], smax['h'], "Height (pes)", "Entries", stype + " height (zoom)")

    ### Energy
    plotVar(se, 100, se.min(), se.max(), "Energy (pes)", "Entries", stype + " energy", text = "", log = True)
    plotVar(se, 100, smin['e'], smax['e'], "Energy (pes)", "Entries", stype + " energy (zoom)")
    
    ### Time position
    plotVar(st, 100, st.min(), st.max(), "Time ($\mu$s)", "Entries", stype + " time position", text = "")

    ### Number vs time
    plot2dVar(tE, sn, 50, 10, tE.min(), tE.max(), 0., 10.,\
              "Event time (s)", "# " + stype, stype + " number vs timestamp")

    ### Energy vs time    
    plot2dVar(tS, se, 50, 50, tS.min(), tS.max(), smin['e'], smax['e'],\
              "Event time (s)", "Energy (pes)", stype + " energy vs timestamp")

# %%
def CreatePlotsSi(sn, q, ID, qi, qimax, nsipm, tE, tS, smin, smax):
    ### Number of peaks
    textPrint = "Total number = {0}\n".format(sn.sum()) + \
                 "With 0 peaks = {0}\n".format(len(sn[sn==0])) + \
                 "Events with 1 = {0}".format(len(sn[sn==1]))
    plotVar(sn, 10, 0, 10, "# S2Si", "Entries", "S2Si number", text  = textPrint)
    
    ### Charge
    plotVar(q, 100, q.min(), q.max(), "Total charge (pes)", "Entries", "S2Si charge", text = "", log = True)
    plotVar(q, 100, smin['q'], smax['q'], "Total charge (pes)", "Entries", "S2Si charge (zoom)")

    ### SiPM charge
    plotVar(qi, 100, qi.min(), qi.max(), "SiPM charge (pes)", "Entries", "SiPM charge", text = "", log = True)
    plotVar(qi, 100, smin['qi'], smax['qi'], "SiPM charge (pes)", "Entries", "SiPM charge (zoom)")
    
    
    ### SiPM max charge
    plotVar(qimax, 100, qimax.min(), qimax.max(), "SiPM max charge (pes)", "Entries", "SiPM max charge", text = "", log = True)
    plotVar(qimax, 100, smin['qimax'], smax['qimax'], "SiPM max charge (pes)", "Entries", "SiPM max charge (zoom)")
    
    ### SiPM max fraction
    qfrac = qimax/q
    plotVar(qfrac, 100, 0., 1., "SiPM max charge (%)", "Entries", "SiPM max charge fraction")

    ### SiPMs touched
    plotVar(nsipm, 1792, 0, 1792, "# touched SiPMs", "Entries", "SiPM number")
 
    ### Detections per SiPM
    plotVar(ID, 1792, 0, 1792, "Channel ID", "# of detections", "SiPM detections")
    
    ### Number vs time
    plot2dVar(tE, sn, 50, 10, tE.min(), tE.max(), 0., 10.,\
              "Event time (s)", "# S2S1", "S2Si number vs timestamp")
    
    ### Charge vs time
    plot2dVar(tS, q, 50, 50, tS.min(), tS.max(), smin['q'], smax['q'],\
              "Event time (s)", "S2Si charge (pes)", "S2Si charge vs timestamp")
    
    ### Detections per SiPM (2D)
    plot2dVar(DataSiPM.X.values[ID], DataSiPM.Y.values[ID], 40, 40, -200., 200., -200., 200.,\
              "x (mm)", "y (mm)", "SiPM detections (2D)")

# %%
def CreatePlotsS1S2Si(s2e, s2s1e, s2s1t, s2sie, tS, onlyS1, smin, smax):

    #S2/S1 ratio
    plotVar(s2s1e, 100, s2s1e.min(), s2s1e.max(), "Ratio", "Entries", "S2/S1 ratio", text = "", log = True)
    plotVar(s2s1e, 100, smin['s2s1e'], smax['s2s1e'], "Ratio", "Entries", "S2/S1 ratio (zoom)")
    
    #S2/S1 time difference
    plotVar(s2s1t, 100, s2s1t.min(), s2s1t.max(), \
            "Time difference ($\mu$s)", "Entries", "S2 - S1 time difference", text = "")

    #Si/S2 ratio
    plotVar(s2sie, 100, s2sie.min(), s2sie.max(), "Ratio", "Entries", "Si/S2 ratio", text = "", log = True)
    plotVar(s2sie, 100, smin['s2sie'], smax['s2sie'], "Ratio", "Entries", "Si/S2 ratio (zoom)")
    
    ### S2 vs S1 charge
    s1e = s2e[onlyS1]/s2s1e
    plot2dVar(s2e[onlyS1], s1e, 50, 50, 0., s2e.max(), 0., s1e.max(),\
              "S2 energy (pes)", "S1 energy (pes)", "S2 charge vs S1 charge", log = True)    
    plot2dVar(s2e[onlyS1], s1e, 50, 50, smin['s2e'], smax['s2e'], smin['s1e'], smax['s1e'],\
              "S2 energy (pes)", "S1 energy (pes)", "S2 charge vs S1 charge (zoom)")

    ### S2/S1 vs time
    plot2dVar(tS[onlyS1], s2s1e, 50, 50, tS.min(), tS.max(), 0., s2s1e.max(),\
              "Event time (s)", "Ratio", "S2/S1 ratio vs timestamp", log = True)
    plot2dVar(tS[onlyS1], s2s1e, 50, 50, tS.min(), tS.max(), smin['s2s1e'], smax['s2s1e'],\
              "Event time (s)", "Ratio", "S2/S1 ratio vs timestamp (zoom)")
    
    ### S2/S1 time difference vs time
    plot2dVar(tS[onlyS1], s2s1t, 50, 50, tS.min(), tS.max(), s2s1t.min(), s2s1t.max(),\
              "Event time (s)", "Time difference ($\mu$s)", "S2/S1 time difference vs timestamp")

    ###Si/S2 vs time
    plot2dVar(tS, s2sie, 50, 50, tS.min(), tS.max(), 0., s2sie.max(),\
              "Event time (s)", "Ratio", "Si/S2 ratio vs timestamp", log = True)
    plot2dVar(tS, s2sie, 50, 50, tS.min(), tS.max(), smin['s2sie'], smax['s2sie'],\
              "Event time (s)", "Ratio", "Si/S2 ratio vs timestamp (zoom)")    

    ### S2/S1 vs S2 energy
    plot2dVar(s2e[onlyS1], s2s1e, 50, 50, 0., s2e.max(), 0., s2s1e.max(),\
              "S2 energy (pes)", "Ratio", "S2/S1 ratio vs S2 energy", log = True)
    plot2dVar(s2e[onlyS1], s2s1e, 50, 50, smin['s2e'], smax['s2e'], smin['s2s1e'], smax['s2s1e'],\
              "S2 energy (pes)", "Ratio", "S2/S1 ratio vs S2 energy (zoom)")
    
    ### S2/S1 time difference vs S2 energy
    plot2dVar(s2e[onlyS1], s2s1t, 50, 50, 0., s2e.max(), s2s1t.min(), s2s1t.max(),\
              "S2 energy (pes)", "Time difference ($\mu$s)", "S2/S1 time difference vs S2 energy", log = True)
    plot2dVar(s2e[onlyS1], s2s1t, 50, 50, smin['s2e'], smax['s2e'], s2s1t.min(), s2s1t.max(),\
              "S2 energy (pes)", "Time difference ($\mu$s)", "S2/S1 time difference vs S2 energy (zoom)")
    
    ###Si/S2 vs S2 energy
    plot2dVar(s2e, s2sie, 50, 50, 0., s2e.max(), 0., s2sie.max(),\
              "S2 energy (pes)", "Ratio", "Si/S2 ratio vs S2 energy", log = True)
    plot2dVar(s2e, s2sie, 50, 50, smin['s2ratio'], smax['s2e'], smin['s2sie'], smax['s2sie'],\
              "S2 energy (pes)", "Ratio", "Si/S2 ratio vs S2 energy (zoom)")   
    
    ###Si/S2 vs S2/S1 time difference
    plot2dVar(s2s1t, s2sie[onlyS1], 50, 50, s2s1t.min(), s2s1t.max(), 0., s2sie.max(),\
              "Time difference ($\mu$s)", "Ratio", "Si/S2 ratio vs S2/S1 time diff", log = True)
    plot2dVar(s2s1t, s2sie[onlyS1], 50, 50, s2s1t.min(), s2s1t.max(), smin['s2sie'], smax['s2sie'],\
              "Time difference ($\mu$s)", "Ratio", "Si/S2 ratio vs S2/S1 time diff (zoom)")            
    
    ### S2/S1 vs S2/S1 time difference
    plot2dVar(s2s1t, s2s1e, 50, 50, s2s1t.min(), s2s1t.max(), 0., s2s1e.max(),\
              "Time difference ($\mu$s)", "Ratio", "S2/S1 ratio vs S2/S1 time diff", log = True)
    plot2dVar(s2s1t, s2s1e, 50, 50, s2s1t.min(), s2s1t.max(), smin['s2s1e'], smax['s2s1e'],\
              "Time difference ($\mu$s)", "Ratio", "S2/S1 ratio vs S2/S1 time diff (zoom)")

# %%
def CreatePlotsSPMT(sw, sh, se, st, tE, smin, smax, npmt):
    ### Width
    plotVarPMT(npmt, sw, 100, smin['w'], smax['w'], "Width (ns)", "Entries", "Width")

    ### Height    
    plotVarPMT(npmt, sh, 100, smin['h']/npmt, smax['h']/npmt, "Height (pes)", "Entries", "Height")

    ### Energy
    plotVarPMT(npmt, se, 100, smin['e']/npmt, smax['e']/npmt, "Energy (pes)", "Entries", "Energy")

    ### Time position
    plotVarPMT(npmt, st, 100, st.min(), st.max(), "Time position ($\mu$s)", "Entries", "Time position")
    
    ### Width vs timestamp
    plot2dVarPMT(npmt, tE, sw, 50, 50, tE.min(), tE.max(), \
                 minS2['w'], maxS2['w'], "Time ($\mu$s)", "Width (ns)", "Width vs timestamp")    

    ### Height vs timestamp
    plot2dVarPMT(npmt, tE, sh, 50, 50, tE.min(), tE.max(), \
                 minS2['h']/npmt, maxS2['h']/npmt, "Time ($\mu$s)", "Height (pes)", "Height vs timestamp") 

    ### Energy vs timestamp
    plot2dVarPMT(npmt, tE, se, 50, 50, tE.min(), tE.max(), \
                 minS2['e']/npmt, maxS2['e']/npmt, "Time ($\mu$s)", "Energy (pes)", "Energy vs timestamp") 

    ### Time position vs timestamp
    plot2dVarPMT(npmt, tE, st, 50, 50, tE.min(), tE.max(), \
                 st.min(), st.max(), "Time ($\mu$s)", "Time position ($\mu$s)", "Time vs timestamp")

# %% [markdown]
# # Load pmaps and values

# %%
s1n = []
s1w = []
s1h = []
s1e = []
s1t = []

s2n = []
s2w = []
s2wthr = []
s2h = []
s2e = []
s2ethr = []
s2t = []

s2sin = []
s2q = []
s2siID = []
s2qi = []
s2qmax = []
s2nsipm = []

s2pmtw = []
s2pmth = []
s2pmte = []
s2pmtt = []

s2_s1_e = []
s2_s1_t = []
s2_s2si_e = []

onlyS1 = []

evt_t = []
evt_tS1 = []
evt_tS2 = []
evt_tS2si = []
evt_tS2sin = []

npmt = 11

for file in inputfiles[:500]:
    try: 
        s1_file, s2_file, s2si_file, _, s2pmt_file = pmapio.load_pmaps_with_ipmt(file)
    except: 
        print("File {} could not be opened".format(file))
    else:
        timestamp = tbf.get_event_numbers_and_timestamps_from_file_name(file)[1]
        for i, evt in enumerate(s2_file):
            evt_t.append(timestamp[i])
            fillSvar(evt, s1_file, s1n, s1w, s1h, s1e, s1t, evt_tS1, timestamp[i])
            fillS2var(evt, s2_file, s2si_file, s2n, s2w, s2wthr, s2h, s2e, s2ethr, s2t, \
                      s2sin, s2q, s2siID, s2qi, s2qmax, s2nsipm, s2_s2si_e, \
                      s1n, s1e, s1t, s2_s1_e, s2_s1_t, onlyS1, \
                      evt_tS2, evt_tS2si, evt_tS2sin, timestamp[i], thr=0.*units.pes)
            fillS2PMTvar(s2pmt_file[evt], s2pmtw, s2pmth, s2pmte, s2pmtt, npmt)

evt_t = (evt_t-evt_t[0])/1000.
evt_tS1 = (evt_tS1-evt_tS1[0])/1000.
evt_tS2 = (evt_tS2-evt_tS2[0])/1000.
evt_tS2si = (evt_tS2si-evt_tS2si[0])/1000.
s2pmtw = np.array(s2pmtw)
s2pmth = np.array(s2pmth)
s2pmte = np.array(s2pmte)
s2pmtt = np.array(s2pmtt)

# %%
len(inputfiles)
# Out:
# 818

# %%
s1n = np.array(s1n)
s1w = np.array(s1w)
s1h = np.array(s1h)
s1e = np.array(s1e)
s1t = np.array(s1t)

s2n = np.array(s2n)
s2w = np.array(s2w)
s2h = np.array(s2h)
s2e = np.array(s2e)
s2t = np.array(s2t)

s2sin = np.array(s2sin)
s2q = np.array(s2q)
s2siID = np.array(s2siID)
s2qi = np.array(s2qi)
s2qmax = np.array(s2qmax)
s2nsipm = np.array(s2nsipm)

s2_s1_e = np.array(s2_s1_e)
s2_s1_t = np.array(s2_s1_t)
s2_s2si_e = np.array(s2_s2si_e)

onlyS1 = np.array(onlyS1)

evt_t = np.array(evt_t)
evt_tS1 = np.array(evt_tS1)
evt_tS2 = np.array(evt_tS2)
evt_tS2si = np.array(evt_tS2si)
evt_tS2sin = np.array(evt_tS2sin)

# %% [markdown]
# # Plots

# %% [markdown]
# ### Plotting limits

# %%
minS1 = {'w':0, 'h':5, 'e':0}
maxS1 = {'w':1000, 'h':150, 'e':1000}

minS2 = {'w':0, 'h':0, 'e':0}
maxS2 = {'w':100e3, 'h':30e3, 'e':600e3}

minS2Si = {'q':0, 'qi':80, 'qimax':0, 'nsipm':0}
maxS2Si = {'q':90e3, 'qi':3000, 'qimax':3000, 'nsipm':500}

minRatio = {'s1e': 0, 's2e':75e3, 's2s1e':0, 's2sie':0., 's2ratio':1000}
maxRatio = {'s1e': 500, 's2e':500e3, 's2s1e':2500, 's2sie':0.5, 's2ratio':500e3}

# %% [markdown]
# ### S1 plots

# %%
CreatePlotsS(np.asarray(s1n), np.asarray(s1w), np.asarray(s1h), np.asarray(s1e), \
             np.asarray(s1t)/1000., evt_t, evt_tS1, "S1", minS1, maxS1)

# %% [markdown]
# ### S2 plots

# %%
CreatePlotsS(np.asarray(s2n), np.asarray(s2w), np.asarray(s2h), np.asarray(s2e), \
             np.asarray(s2t)/1000., evt_t, evt_tS2, "S2", minS2, maxS2)

# %% [markdown]
# ### S2Si plots

# %%
CreatePlotsSi(np.asarray(s2sin), np.asarray(s2q), np.asarray(s2siID), np.asarray(s2qi), \
              np.asarray(s2qmax), np.asarray(s2nsipm), evt_t, evt_tS2si, minS2Si, maxS2Si)

# %% [markdown]
# ### Ratio plots

# %%
CreatePlotsS1S2Si(np.asarray(s2e), np.asarray(s2_s1_e), np.asarray(s2_s1_t)/1000., \
                  np.asarray(s2_s2si_e), np.asarray(evt_tS2), np.asarray(onlyS1), minRatio, maxRatio)

# %% [markdown]
# ### S2pmt plots

# %%
CreatePlotsSPMT(s2pmtw, s2pmth, s2pmte, s2pmtt/1000., np.asarray(evt_tS2), minS2, maxS2, 11)
